# %%
import numpy as np
from scipy.io import wavfile
import matplotlib.pyplot as plt

PATHTOSPEECH = r'U:\py\sounds-phd\01_algorithms\01_NR\02_distributed\dev\danse_simple\wav'

fs, data1 = wavfile.read(f'{PATHTOSPEECH}/noisy_N1_Sref1.wav')
fs, data2 = wavfile.read(f'{PATHTOSPEECH}/noisy_N2_Sref1.wav')

sigs = np.concatenate((data1[:, np.newaxis], data2[:, np.newaxis]), axis=1)

plt.plot(sigs)
